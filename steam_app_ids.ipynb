# %% [markdown]
# # Build a scraper to collect Steam App store data
#
# The current dataset collected on Steam games was a but outdated.
# So instead we will scrape a new data set for analysis.
# The scraping method used here was borrowed from Nik Davis' GitHub (https://nik-davis.github.io/posts/2019/steam-data-collection/)
# I have modified parts of the method to suit my needs here.

# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
from time import sleep, time
import requests
import pandas as pd
import numpy as np
from random import randint
from bs4 import BeautifulSoup
import pickle

# %%
response = requests.get('https://api.steampowered.com/ISteamApps/GetAppList/v2/?')
applist = response.json()

# %%
steam_app_ids = pd.DataFrame(applist['applist']['apps'])
steam_app_ids.to_pickle('steam_app_list.p')
steam_app_ids['appid'].head()
# Out:
# 0    562398
# 1    562399
# 2    562410
# 3    562420
# 4    562430
# Name: appid, dtype: int64

# %%
# steam apps games scrape
def get_request(url, parameters=None):
    # return json format data about apps in steam app store
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        sleep(randint(1,3))
        print('\rRetrying.' + ' '*10)
        
        # recursively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        sleep(10)
        print('Retrying.')
        return get_request(url, parameters)

# %%
def app_parser(app_id):
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids":  app_id}
    json_data = requests.get(url, params= parameters).json()
    json_app_data = json_data[str(app_id)]
    if json_app_data['success']:
        app_data = json_app_data['data']
        details = ['type','steam_appid','name','release_date','reviews','developers','publishers','metacritic','platforms','genres','required_age']
        app_details = []
        for detail in details:
            try:
                app_details.append(app_data[detail])
            except:
                app_details.append(np.NaN)
                pass
        try:    
            app_details[3] = app_details[3]['date']
        except:
            pass
        try:
            app_details[4] = BeautifulSoup(app_details[4]).get_text() 
        except:
            pass
        try:    
            app_details[7] = app_details[7]['score']
        except:
            pass
        try:    
            app_details[9] = [x['description'] for x in app_details[9]]
        except:
            pass
    else:
        app_details = [np.NaN, np.NaN, np.NaN,np.NaN, np.NaN,np.NaN, np.NaN, np.NaN,np.NaN, np.NaN, np.NaN]

    return app_details

# %%
import csv
import pickle

columns = ['type','steam_appid','name','release_date','reviews','developers','publishers','metacritic','platforms','genres','required_age']
details = []
csv_file = open('steam_apps_dataset.csv', 'w', encoding = 'utf-8')
csv_writer= csv.writer(csv_file, delimiter= ',')

for ids in steam_app_ids['appid'][0:10000]:
    apps_written = 0
    row = app_parser(ids)
    csv_writer.writerow(row)
    details.append(row)
    apps_written += 1
    sleep(randint(1,3))
    if len(details) % 1000 == 0.0:
        print(f"About to pickle data, don't stop script!")     
        with open('steam_data_list.p','wb') as f:
            pickle.dump(details,f)
        print(f'Completed {apps_written} app details') 
        sleep(2)       
    else:    
        sleep(1)

csv_file.close     
details

# %%
pickledeets = pickle.load(open('steam_data_list.p', 'rb'))
deets = pd.DataFrame(pickledeets, columns = columns)
deets['metacritic'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 9995   NaN
# 9996   NaN
# 9997   NaN
# 9998   NaN
# 9999   NaN
# Name: metacritic, Length: 10000, dtype: float64>

# %%
columns = ['type','steam_appid','name','release_date','reviews','developers','publishers','metacritic','platforms','genres','required_age']
details = []
csv_file = open('steam_apps_dataset4.csv', 'w', encoding = 'utf-8')
csv_writer= csv.writer(csv_file, delimiter= ',')
apps_written = 0
for ids in steam_app_ids['appid'][22001:40000]:
    row = app_parser(ids)
    csv_writer.writerow(row)
    details.append(row)
    apps_written += 1
    sleep(randint(1,3))
    if len(details) % 1000 == 0.0:
        print(f"About to pickle data, don't stop script!")     
        with open('steam_data_list4.p','wb') as f:
            pickle.dump(details,f)
        print(f'Completed {apps_written} app details') 
        sleep(2)       
    else:    
        sleep(1)

csv_file.close     
details
# Out:
# About to pickle data, don't stop script!
# Completed 1000 app details
# About to pickle data, don't stop script!
# Completed 2000 app details
# About to pickle data, don't stop script!
# Completed 3000 app details
# About to pickle data, don't stop script!
# Completed 4000 app details
# About to pickle data, don't stop script!
# Completed 5000 app details
# About to pickle data, don't stop script!
# Completed 6000 app details
# About to pickle data, don't stop script!
# Completed 7000 app details
# About to pickle data, don't stop script!
# Completed 8000 app details
# About to pickle data, don't stop script!
# Completed 9000 app details
# About to pickle data, don't stop script!
# Completed 10000 app details
# About to pickle data, don't stop script!
# Completed 11000 app details
# About to pickle data, don't stop script!
# Completed 12000 app details
# About to pickle data, don't stop script!
# Completed 13000 app details
# About to pickle data, don't stop script!
# Completed 14000 app details
# About to pickle data, don't stop script!
# Completed 15000 app details
# About to pickle data, don't stop script!
# Completed 16000 app details
# About to pickle data, don't stop script!
# Completed 17000 app details
# [['episode',
#   530446,
#   'Battle Disc: Agressive Opponent Dink!',
#   '21 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530447,
#   'Battle Disc: Mia Sows Discord!',
#   '21 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530448,
#   'Battle Disc: Reunion of the Rockson Brothers!',
#   '21 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530449,
#   'Battle Disc: Dignity of The Warrior!',
#   '21 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530450,
#   'Battle Disc: The Fight of Six Warriors!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530451,
#   'Battle Disc: The Birth of Mega Warrior!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530452,
#   'Battle Disc: Raising of the Darkness Disc!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530453,
#   'Battle Disc: Counterattack by Moses!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530454,
#   'Battle Disc: Battle Between Geniuses!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530455,
#   'Battle Disc: Threat from Little Devil!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530456,
#   'Battle Disc: The Mind Reader Reemerges, The Dark Triplets!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530457,
#   'Battle Disc: Faction In Between!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530458,
#   'Battle Disc: Unexpected Defeat!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530459,
#   "Battle Disc: Ken's Counterattack",
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530460,
#   'Battle Disc: The Light of Friendship!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530461,
#   'Battle Disc: Re-fight Kobe, Be Secure of Victory!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530462,
#   'Battle Disc: King of Battle Disc!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530463,
#   'Battle Disc: Battle! Good and Evil!',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   530464,
#   'Battle Disc: Victory! A Brand New World',
#   '4 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['game',
#   530470,
#   'S#arp Shooter',
#   'Coming Soon',
#   nan,
#   ['Complex Infinity'],
#   ['Complex Infinity'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['dlc',
#   529930,
#   'Banned Footage Vol.1',
#   '20 Feb, 2017',
#   nan,
#   ['CAPCOM Co., Ltd.'],
#   ['CAPCOM Co., Ltd.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Violent', 'Gore', 'Action', 'Adventure'],
#   0],
#  ['game',
#   529940,
#   'ShowdownVR',
#   '19 Sep, 2016',
#   nan,
#   ['Frontseat Studio'],
#   ['Frontseat Studio'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   529950,
#   '12 orbits',
#   '24 Oct, 2016',
#   nan,
#   ['Roman Uhlig'],
#   ['Roman Uhlig'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Casual', 'Indie', 'Sports'],
#   0],
#  ['game',
#   529970,
#   'PositronX',
#   '29 Oct, 2020',
#   nan,
#   ['Scorpius Games'],
#   ['Scorpius Games'],
#   63,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['demo',
#   529980,
#   'Book of Demons Demo',
#   '27 Oct, 2016',
#   nan,
#   ['Thing Trunk'],
#   ['Thing Trunk'],
#   72,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Indie', 'RPG'],
#   0],
#  ['game',
#   530010,
#   'Water Heroes: A Game for Change',
#   '1 Mar, 2017',
#   nan,
#   ['Classplash'],
#   ['Classplash'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Indie'],
#   0],
#  ['game',
#   530020,
#   'World to the West',
#   '5 May, 2017',
#   nan,
#   ['Rain Games'],
#   ['Rain Games'],
#   75,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Adventure', 'Indie', 'RPG'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   530040,
#   'reconquest',
#   '16 Dec, 2016',
#   nan,
#   ['StormCube Games'],
#   ['StormCube Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Strategy'],
#   0],
#  ['demo',
#   530050,
#   'Sumeru Demo',
#   '20 Sep, 2016',
#   nan,
#   ['BigCheeseGames'],
#   ['BigCheeseGames'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   530060,
#   'Overcooked - The Lost Morsel',
#   '15 Nov, 2016',
#   nan,
#   ['Ghost Town Games Ltd.'],
#   ['Team17 Digital Ltd'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   530070,
#   'Train Sim World® 2020',
#   '16 Mar, 2017',
#   nan,
#   ['Dovetail Games'],
#   ['Dovetail Games - TSW'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Simulation'],
#   0],
#  ['game',
#   530080,
#   'Super Toaster X: Learn Japanese RPG',
#   '22 Jan, 2017',
#   nan,
#   ['Team Toaster'],
#   ['Team Toaster'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'RPG', 'Early Access'],
#   0],
#  ['demo',
#   530090,
#   'Hacker Evolution IMMERSION Demo',
#   '23 Sep, 2016',
#   nan,
#   ['exosyphen studios'],
#   ['exosyphen studios'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   530110,
#   'Tales of a Spymaster',
#   '17 May, 2019',
#   '“Leading a nation torn apart by war weariness and illness is sure to only end in disaster, and each of the toys at your disposal are also at the hands of the rival spymasters out there. Is it just me, or is that really, really interesting and fun sounding?”https://bigbossbattle.com/greenlight-highlight-tales-spymaster/',
#   ['Gerard Morris'],
#   ['Gerard Morris'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action',
#    'Casual',
#    'Indie',
#    'RPG',
#    'Simulation',
#    'Strategy',
#    'Early Access'],
#   0],
#  ['game',
#   530120,
#   'VR The Diner Duo',
#   '2 Nov, 2016',
#   nan,
#   ['Whirlybird Games'],
#   ['Whirlybird Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   530130,
#   'Akuto: Showdown',
#   '28 Mar, 2019',
#   "“It's all about making a bloody mess of your friends”IndieGames“A few goes in, but only one stands alive”Future Beta Gamer",
#   ['Hut 90'],
#   ['Hut 90'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   530140,
#   "Sisyphus Reborn - Collector's Edition",
#   '23 Sep, 2016',
#   nan,
#   ['Myshkin Entertainment'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': True},
#   ['Adventure'],
#   0],
#  ['dlc',
#   530150,
#   'The Exiled - Nomad Pack',
#   '23 Feb, 2017',
#   nan,
#   ['Fairytale Distillery'],
#   ['Fairytale Distillery'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Massively Multiplayer', 'RPG'],
#   0],
#  ['dlc',
#   530151,
#   'The Exiled - Seeker Pack',
#   '23 Feb, 2017',
#   nan,
#   ['Fairytale Distillery'],
#   ['Fairytale Distillery'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Massively Multiplayer', 'RPG'],
#   0],
#  ['dlc',
#   530152,
#   'The Exiled - Vanguard Pack',
#   '23 Feb, 2017',
#   nan,
#   ['Fairytale Distillery'],
#   ['Fairytale Distillery'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Massively Multiplayer', 'RPG'],
#   0],
#  ['game',
#   530160,
#   'Eve of Destruction - REDUX VIETNAM',
#   '29 Sep, 2016',
#   nan,
#   ['Lotte|EoD'],
#   ['Agger Interactive'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action',
#    'Adventure',
#    'Casual',
#    'Indie',
#    'Massively Multiplayer',
#    'Simulation',
#    'Strategy'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   530180,
#   'Party Hard - Dark Castle',
#   '16 Sep, 2016',
#   nan,
#   ['Pinokl Games'],
#   ['tinyBuild'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Indie', 'Strategy'],
#   '16'],
#  ['demo',
#   530190,
#   'King Machine Demo',
#   '2 Nov, 2016',
#   nan,
#   ['FastRam Design'],
#   ['FastRam Design'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['demo',
#   530210,
#   'INSIDE Demo',
#   '24 Nov, 2016',
#   nan,
#   ['Playdead'],
#   ['Playdead'],
#   87,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   530280,
#   'Fantasy Grounds - Ruleset: Barbarians of Lemuria',
#   '19 Sep, 2016',
#   nan,
#   ['SmiteWorks USA, LLC'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'RPG', 'Strategy'],
#   0],
#  ['game',
#   530290,
#   'The Planet of the Vicious Creatures',
#   '5 Oct, 2016',
#   nan,
#   ['Jorge Giner Cordero'],
#   ['Jorge Giner Cordero'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   530300,
#   'Slymes',
#   '25 Nov, 2016',
#   nan,
#   ['WolfTech Games'],
#   ['WolfTech Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Massively Multiplayer'],
#   0],
#  ['video',
#   530310,
#   'Sex and Broadcasting: a Film About Wfmu',
#   '7 Nov, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   nan,
#   0],
#  ['game',
#   530320,
#   'Wandersong',
#   '27 Sep, 2018',
#   "“As if the developers are hugging you from the opposite part of the screen.”Bestest Best – RockPaperShotgun“A rollercoaster ride through the spectrum of feelings... one I'll never forget.”9/10 – Destructoid“Loss, acceptance, regret, friendship, and the intimacy of colliding with another person's life. It's usually funny, but sometimes sad...”88/100 – PC Gamer",
#   ['Greg Lobanov', 'A Shell in the Pit'],
#   ['Greg Lobanov'],
#   82,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Indie'],
#   0],
#  ['game',
#   530330,
#   'Blameless',
#   '13 Oct, 2016',
#   nan,
#   ['Vaclav Hudec'],
#   ['Blameless Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   530340,
#   'Flub Fighter',
#   '27 Feb, 2017',
#   nan,
#   ['Retora Game Studios LLC'],
#   ['Retora Game Studios LLC'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   530350,
#   'Smashbox Arena',
#   '7 Dec, 2016',
#   '“This is what happens when Counter-Strike meets Mario Kart in VR...And it’s way more fun that it has any right to be.”Polygon“Smashbox Arena is my favorite multiplayer VR game that you have never heard of - until today.”Chet Faliszek“BigBox VR has tapped into a special kind of addictive fun you don’t find in most VR games yet.”UploadVR',
#   ['BigBox VR, Inc.'],
#   ['BigBox VR, Inc.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   530360,
#   'Requiescence',
#   '22 Sep, 2016',
#   nan,
#   ['Argent Games'],
#   ['Argent Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual'],
#   0],
#  ['game',
#   530370,
#   "Warlock's Tower",
#   '31 Jan, 2017',
#   '“Warlock’s Tower is a wonderful old-school puzzle game, it is only relaxing if you like torturing your brain”Digital Crack Network“While levels start out fairly straightforward, Warlock’s Tower quickly develops into a deep and challenging puzzler.”Rock Paper Shotgun“It’s a fun and addictive little game, full of bite-sized puzzles that require some real foresight and planning to conquer.  This mailman really is going above and beyond the call of duty in this charming and challenging puzzler!”Alpha Beta Gamer',
#   ['Midipixel'],
#   ['Whippering'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Indie'],
#   0],
#  ['game',
#   530390,
#   'Slayaway Camp',
#   '25 Oct, 2016',
#   nan,
#   ['Blue Wizard Digital'],
#   ['Blue Wizard Digital'],
#   83,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual', 'Indie', 'Strategy'],
#   0],
#  ['series',
#   530400,
#   'Battle Disc',
#   '14 Oct, 2016',
#   nan,
#   ['Anitime Animation Studio'],
#   ['TomMo Media'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   nan,
#   0],
#  ['demo',
#   530410,
#   'Evil Orbs Demo',
#   '27 Oct, 2016',
#   nan,
#   ['GoBit Games'],
#   ['GoBit Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['episode',
#   530420,
#   'Battle Disc: Exploring Disc Planet, begin!',
#   '26 Sep, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   529440,
#   'Behold the Kickmen',
#   '20 Jul, 2017',
#   '“Brilliant, brilliant football”N/A – Nerd³“the ultimate football sim... makes getting football wrong just right”N/A – The Guardian',
#   ['Size Five Games'],
#   ['Size Five Games'],
#   58,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Sports'],
#   0],
#  ['game',
#   529450,
#   'I Know a Tale',
#   '20 Sep, 2016',
#   nan,
#   ['Hoshko'],
#   ['Hoshko'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  ['music',
#   529470,
#   'Pankapu - Official Soundtrack',
#   '21 Sep, 2016',
#   nan,
#   ['Too Kind Studio'],
#   ['Dear Villagers'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   529490,
#   'Rogue Trooper Redux',
#   '17 Oct, 2017',
#   nan,
#   ['TickTock Games'],
#   ['Rebellion'],
#   60,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure'],
#   0],
#  ['game',
#   529500,
#   'ALONE? - VR',
#   '7 Oct, 2016',
#   nan,
#   ['Deceptive Games Ltd.'],
#   ['Deceptive Games Ltd.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Indie'],
#   0],
#  ['game',
#   529520,
#   'Mutant Football League',
#   '31 Oct, 2017',
#   "“Mutant Football League brings back visions of the over-the-top arcade sports games of yesteryear”6.75/10 – Game Informer“The classic game's return is intentionally rough around the edges”3.5/5 – Sporting News“A retro revival given a modern coat of paint, Mutant Football League sticks to its 16-bit roots and showcases the funnier, gorier, side of American football.”3.5/5 – PCMag",
#   ['Digital Dreams Entertainment LLC'],
#   ['Digital Dreams Entertainment LLC'],
#   74,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'Sports'],
#   '18'],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   529540,
#   'Thread Studio',
#   '29 Sep, 2016',
#   nan,
#   ['Shopify'],
#   ['Shopify'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Design & Illustration'],
#   0],
#  ['dlc',
#   529550,
#   'Dragon Bros - Original Soundtrack',
#   '16 Sep, 2016',
#   nan,
#   ['Space Lizard Studio LTD'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['game',
#   529580,
#   "Kyurinaga's Revenge",
#   '25 Oct, 2016',
#   nan,
#   ['Recotechnology S.L.'],
#   ['Recotechnology S.L.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure'],
#   0],
#  ['game',
#   529590,
#   "Please, Don't Touch Anything 3D",
#   '7 Dec, 2016',
#   '“If you’re looking for a puzzle game that will make you both laugh and jump, I can easily recommend Please, Don’t Touch Anything, even if you’ve played the original.”9/10 – Destructoid',
#   ['Escalation Studios', 'Four Quarters'],
#   ['Forward Game Studios'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  ['demo',
#   529600,
#   'Beeftacular Demo',
#   '13 Sep, 2016',
#   nan,
#   ['Retrific'],
#   ['Retrific'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Racing', 'Sports'],
#   0],
#  ['game',
#   529610,
#   'FISH LAKE',
#   '16 Dec, 2016',
#   nan,
#   ['7 Generation Games'],
#   ['7 Generation Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Strategy'],
#   0],
#  ['dlc',
#   529620,
#   'Infested Planet - Planetary Campaign',
#   '10 Oct, 2016',
#   nan,
#   ['Rocket Bear Games'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   529630,
#   'The Rabbit Hole Remastered',
#   '26 May, 2017',
#   nan,
#   ['VRMonkey'],
#   ['VRMonkey'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   529640,
#   'SteamVR Driver for FOVE',
#   '11 Jan, 2019',
#   nan,
#   ['FOVE, Inc.'],
#   ['FOVE, Inc.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['game',
#   529660,
#   'Mages of Mystralia',
#   '18 May, 2017',
#   "“I honestly had a blast playing it.”9.2/10 – Marooners' Rock“Mages of Mystralia [...] révolutionne tous les systèmes de magie en jeux vidéo.”9/10 – Jeux[dot]ca“Piecing all of those runes into a new master spell made me feel like the most creative mage who’d ever lived.”8/10 – Game Informer",
#   ['Borealys Games'],
#   ['Borealys Games'],
#   74,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   529670,
#   'The Bellows',
#   '13 Sep, 2016',
#   nan,
#   ['BOT Jungle Productions', 'Evan Davis', 'Bryce Davis', 'Gehrig Gosslin'],
#   ['BOT Jungle Productions'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Simulation'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   529690,
#   'Graviteam Tactics: Croatian Legion',
#   '6 Oct, 2016',
#   nan,
#   ['Graviteam'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Simulation', 'Strategy'],
#   0],
#  ['game',
#   529700,
#   'Total Extreme Wrestling 2013',
#   '2 Dec, 2016',
#   nan,
#   ['Grey Dog Software'],
#   ['Viva Media'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Sports'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   529730,
#   'Seabed Prelude',
#   '24 Feb, 2017',
#   nan,
#   ['MythicOwl'],
#   ['MythicOwl'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['demo',
#   529740,
#   'The Rabbit Hole Demo',
#   '11 Oct, 2016',
#   nan,
#   ['VRMonkey'],
#   ['VRMonkey'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie', 'Strategy'],
#   0],
#  ['dlc',
#   529750,
#   'Klang Soundtrack',
#   '22 Sep, 2016',
#   nan,
#   ['Tinimations'],
#   ['Snow Cannon Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   529760,
#   'TAIKU MANSION',
#   '13 Feb, 2017',
#   nan,
#   ['ST. TAIKU', 'KITATUS'],
#   ['KITATUS'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure'],
#   0],
#  ['game',
#   529770,
#   'Ley Lines',
#   '5 Dec, 2016',
#   nan,
#   ['Miria Studios'],
#   ['Miria Studios'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   529780,
#   'Disturbed',
#   '3 Oct, 2016',
#   nan,
#   ['iBlackpen'],
#   ['iBlackpen'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Casual', 'Free to Play', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   529790,
#   'Gone with the Demon',
#   '25 Jan, 2017',
#   '“Bone crunching first person dungeon brawling that requires skill and strategy to survive.”Alpha Beta Gamer',
#   ['BoyAndWitch Studio'],
#   ['BoyAndWitch Studio'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'RPG', 'Early Access'],
#   0],
#  ['game',
#   529820,
#   'Beyond Power VR',
#   '30 Sep, 2016',
#   nan,
#   ['Unparalleled Games'],
#   ['Unparalleled Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   529840,
#   'Brawl of Ages',
#   '12 Sep, 2017',
#   nan,
#   ['BNA Studios, LLC'],
#   ['S2 Games, LLC'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Free to Play', 'Strategy'],
#   0],
#  ['demo',
#   529850,
#   'BLADE ARCUS from Shining: Battle Arena Demo',
#   '29 Sep, 2016',
#   nan,
#   ['Studio Saizensen'],
#   ['Studio Saizensen'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   529860,
#   'ColecoVision Flashback',
#   '7 Oct, 2016',
#   nan,
#   ['AtGames'],
#   ['AtGames'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual'],
#   0],
#  ['game',
#   529890,
#   'Maniac Mansion',
#   '18 Dec, 2017',
#   nan,
#   ['Lucasfilm Games'],
#   ['Lucasfilm', 'Disney'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure'],
#   0],
#  ['game',
#   529900,
#   'Polygon Attack',
#   '27 Dec, 2016',
#   nan,
#   ['Magnolia Art'],
#   ['Magnolia Art'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': True},
#   ['Action', 'Adventure', 'Casual', 'Indie'],
#   0],
#  ['game',
#   529910,
#   'ARK Park',
#   '21 Mar, 2018',
#   nan,
#   ['Snail Games'],
#   ['Snail Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure'],
#   0],
#  ['game',
#   528940,
#   'Birthright Cataclysm - Overture',
#   '9 Dec, 2020',
#   nan,
#   ['Hisoka'],
#   ['Hisoka'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Free to Play', 'Indie', 'RPG'],
#   '18'],
#  ['game',
#   528950,
#   'Nekuia',
#   '16 Dec, 2016',
#   "“Les concepts les plus simples sont parfois les plus efficaces, surtout lorsqu'ils sont correctement exécutés !”IndieMag“Pour leur première réalisation, Blue Gate a frappé fort et leur jeu d'arcade a vraiment de quoi intéresser les joueurs avide de vitesse”GameWave",
#   ['Blue Gate'],
#   ['Plug In Digital'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   528960,
#   'Blanco: The Color of Adventure',
#   '23 Dec, 2016',
#   nan,
#   ['51Pegasi Studios'],
#   ['51Pegasi Studios'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Indie', 'Early Access'],
#   0],
#  ['game',
#   528970,
#   'SOS Survival',
#   '31 Oct, 2018',
#   nan,
#   ['StudioFriends'],
#   ['StudioFriends'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'RPG'],
#   0],
#  ['game',
#   528980,
#   'Arakion: Book One',
#   '15 May, 2018',
#   nan,
#   ['Arakion LLC', 'Lavidimus'],
#   ['Arakion LLC'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'RPG', 'Early Access'],
#   0],
#  ['game',
#   528990,
#   'Basketball Babe',
#   '2 Oct, 2016',
#   nan,
#   ['VACTOR'],
#   ['VACTOR'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Sports'],
#   0],
#  ['dlc',
#   529010,
#   'Negligee - Wallpapers',
#   '19 Oct, 2016',
#   nan,
#   ['Dharker Studio'],
#   ['Dharker Studios Ltd'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  ['game',
#   529020,
#   'Virtual-O',
#   '7 Dec, 2016',
#   nan,
#   ['Contours'],
#   ['Contours'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Simulation', 'Sports', 'Early Access'],
#   0],
#  ['dlc',
#   529030,
#   'Barrow Hill: Curse of the Ancient Circle - Soundtrack',
#   '22 Sep, 2016',
#   nan,
#   ['Shadow Tor Studios'],
#   ['Iceberg Interactive'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie'],
#   0],
#  ['game',
#   529040,
#   'Fine China',
#   '5 May, 2017',
#   '“Lots of destructive fun with solid visuals for a steal. Get it!”UploadVR',
#   ['Fine China Games'],
#   ['Fine China Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie', 'Simulation'],
#   0],
#  ['dlc',
#   529050,
#   'Clustertruck OST',
#   '27 Sep, 2016',
#   nan,
#   ['Landfall', 'Karl Flodin'],
#   ['tinyBuild'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Casual', 'Indie', 'Racing'],
#   0],
#  ['game',
#   529060,
#   'Space Simulator',
#   '26 Feb, 2018',
#   nan,
#   ['Stuka Games Inc'],
#   ['Brixton Dynamics Ltd'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Simulation', 'Early Access'],
#   0],
#  ['game',
#   529070,
#   'Retaliation Path of Rome',
#   'Q1 2017',
#   nan,
#   ['XTeam Software Solutions'],
#   ['XTeam Software Solutions'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   529090,
#   'Violet Haunted',
#   '21 Oct, 2016',
#   nan,
#   ['Donnie D. Washington II'],
#   ['Donnie D. Washington II'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['RPG'],
#   0],
#  ['game',
#   529100,
#   'Omni Link',
#   '4 Sep, 2018',
#   nan,
#   ['Roencia'],
#   ['Roencia Game Creators'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   529110,
#   'Awkward Dimensions Redux',
#   '21 Oct, 2016',
#   nan,
#   ['StevenHarmonGames'],
#   ['StevenHarmonGames'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   529130,
#   'Expect The Unexpected',
#   '8 Dec, 2016',
#   '“This have many elements of FTL, its like the ftl but with swords and arrows. The replay-value is great”The Emperor Of Light“This is a surprisingly fun game for people who like RPGs, roguelike, and tactical games. The combat is solid for a game of this type.”Shinop87“I love this game, it uses a similar formula to FTL regarding the world map, random events and resource management, but the combat and exploration follows the Rogue style.”Biterkid',
#   ['GoldenGod Games'],
#   ['GoldenGod Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual', 'Indie', 'RPG', 'Strategy'],
#   0],
#  ['game',
#   529140,
#   'Ulama: Arena of the Gods',
#   '28 Mar, 2017',
#   nan,
#   ['Trainwreck Games'],
#   ['Trainwreck Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'Sports', 'Early Access'],
#   0],
#  ['game',
#   529150,
#   'Lazerbait',
#   '13 Oct, 2016',
#   "“Without exaggerating, this has become my most played Vive game.”\r\n- Beta Tester\n\r\n“Dude. This game is ******* amazing.”\r\n- Beta Tester\n\r\n“I'm absolutely not done playing, it's totally the kind of game I need.”\r\n- Beta Tester\n",
#   ['Taylor Stapleton'],
#   ['Taylor Stapleton'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Strategy'],
#   0],
#  ['game',
#   529160,
#   'Moekuri: Adorable + Tactical SRPG',
#   '16 Dec, 2016',
#   "“If you like bright colours and cuteness, you’ll love Moekuri”9/10 – Leviathyn: The Gamer's Chronicle“...A solid strategy RPG with plenty of inventive ideas...”4/5 – JRPG Moe",
#   ['MokyuSoft'],
#   ['Culture Select'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'RPG', 'Strategy'],
#   0],
#  ['dlc',
#   529170,
#   'MineSweeper VR: Zombies',
#   '17 Oct, 2016',
#   nan,
#   ['Funny Twins'],
#   ['Funny Twins'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Violent', 'Gore', 'Action', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['music',
#   529190,
#   'On A Roll 3D - Soundtrack',
#   '13 Sep, 2016',
#   nan,
#   ['Battenberg Software'],
#   ['Battenberg Software'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Adventure', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   529200,
#   'Streamline Original Sound Track',
#   '30 Sep, 2016',
#   nan,
#   ['Proletariat Inc.'],
#   ['Proletariat Inc.'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Indie', 'Sports'],
#   0],
#  ['game',
#   529240,
#   'Creature Clicker - Capture, Train, Ascend!',
#   '28 Apr, 2017',
#   nan,
#   ['ColloseusX'],
#   ['Phat Phrog Studios'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Early Access'],
#   0],
#  ['game',
#   529260,
#   'Robot Incursion',
#   '21 Nov, 2016',
#   nan,
#   ['MobileFusion Apps Ltd'],
#   ['MobileFusion Apps Ltd'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   529280,
#   'TEOT - The End OF Tomorrow',
#   '30 Sep, 2016',
#   nan,
#   ['Edsenses Creative Co., Ltd'],
#   ['Edsenses Creative Co., Ltd'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action',
#    'Adventure',
#    'Casual',
#    'RPG',
#    'Simulation',
#    'Strategy',
#    'Early Access'],
#   0],
#  ['demo',
#   529310,
#   'Blanco Demo',
#   '12 Sep, 2016',
#   nan,
#   ['51Pegasi Studios'],
#   ['51Pegasi Studios'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   529340,
#   'Victoria 3',
#   'To Be Announced',
#   nan,
#   ['Paradox Development Studio'],
#   ['Paradox Interactive'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Simulation', 'Strategy'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   529360,
#   'Void Rangers',
#   '11 May, 2017',
#   nan,
#   ['Martin Senovsky'],
#   ['Martin Senovsky'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['dlc',
#   529390,
#   'Wargame: Red Dragon - Nation Pack: Israel',
#   '4 Oct, 2016',
#   nan,
#   ['Eugen Systems'],
#   ['Eugen Systems'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Strategy'],
#   0],
#  ['dlc',
#   529400,
#   'Starship Annihilator - Soundtrack',
#   '13 Sep, 2016',
#   nan,
#   ['IR Studio'],
#   ['IR Studio'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   529410,
#   'Kittypocalypse - Ungoggled',
#   '3 Nov, 2016',
#   nan,
#   ['Bolverk Games'],
#   ['Bolverk Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   529420,
#   'Crazy Sapper 3D',
#   '26 Oct, 2016',
#   nan,
#   ['Aratog LLC'],
#   ['Big Black Bear'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie'],
#   0],
#  ['episode',
#   528530,
#   'Dirty 30: About Last Night Meme Gallery',
#   '23 Sep, 2016',
#   nan,
#   ['Lionsgate'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['game',
#   528580,
#   'Found',
#   '14 Sep, 2016',
#   nan,
#   ['Priyam Parikh',
#    'Andrew Moran',
#    'Jake Stull',
#    'Jewel Lim',
#    'Niko Korolog',
#    'Aaron Bales'],
#   ['FoundVR'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual', 'Free to Play', 'Indie', 'Early Access'],
#   0],
#  ['video',
#   528590,
#   'Gaming the Real World',
#   '30 Sep, 2016',
#   nan,
#   ['Lucky Day'],
#   ['Paradox Interactive'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   nan,
#   0],
#  ['game',
#   528610,
#   'Double Dragon IV',
#   '30 Jan, 2017',
#   nan,
#   ['Arc System Works'],
#   ['Arc System Works'],
#   50,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['dlc',
#   528620,
#   'Order of Battle: Blitzkrieg',
#   '10 Nov, 2016',
#   nan,
#   ['The Artistocrats'],
#   ['Slitherine Ltd.'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Simulation', 'Strategy'],
#   0],
#  ['dlc',
#   528630,
#   'A Blind Legend - Original Soundtrack',
#   '15 Sep, 2016',
#   nan,
#   ['Dowino'],
#   ['Plug In Digital'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   528640,
#   'Rugby Union Team Manager 2017',
#   '25 Nov, 2016',
#   nan,
#   ['Alternative Software Ltd'],
#   ['Alternative Software Ltd'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Simulation', 'Sports', 'Strategy'],
#   0],
#  ['game',
#   528660,
#   'Spin Rush',
#   '16 Sep, 2016',
#   nan,
#   ['EGAMER'],
#   ['EGAMER'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['game',
#   528670,
#   'Elems',
#   '11 Nov, 2016',
#   nan,
#   ['Fifth Dimension Company'],
#   ['Fifth Dimension Company'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  ['demo',
#   528690,
#   'SteamDolls Demo',
#   '31 Oct, 2016',
#   nan,
#   ['The Shady Gentlemen'],
#   ['The Shady Gentlemen'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   528720,
#   'Shu',
#   '4 Oct, 2016',
#   '“In terms of execution and gameplay, Shu is near enough perfect… from start to finish, Shu was buttery smooth – and an absolute pleasure to control”10/10 – Gamespew“A Great Beginning to a Possible Classic”9.5/10 – BagoGames“It just seemed to get everything right and it certainly deserves to stand tall along the likes of the classic platforming greats”9.2/10 – Use A Potion',
#   ['Coatsink', 'Secret Lunch'],
#   ['Coatsink'],
#   85,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   528730,
#   'Crypt of the Serpent King',
#   '27 Dec, 2016',
#   nan,
#   ['Rendercode Games'],
#   ['Rendercode Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'RPG'],
#   0],
#  ['game',
#   528740,
#   'Operation: New Earth',
#   '14 Dec, 2016',
#   nan,
#   ['Hunted Cow Studios'],
#   ['Hunted Cow Studios'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Free to Play', 'Massively Multiplayer', 'Simulation', 'Strategy'],
#   0],
#  ['game',
#   528770,
#   'Twixel',
#   '18 Nov, 2016',
#   nan,
#   ['Caesoose Studios'],
#   ['Self Published'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   528790,
#   'Francois BOUILLE',
#   '20 Sep, 2016',
#   nan,
#   ['François Bouille - Experience 360'],
#   ['François Bouille - Experience 360'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Education', 'Utilities'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   528820,
#   'Eisenwald: Blood of November',
#   '1 Nov, 2016',
#   nan,
#   ['Aterdux Entertainment'],
#   ['Aterdux Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie', 'RPG', 'Strategy'],
#   0],
#  ['game',
#   528860,
#   'Proxy - Ultimate Hacker',
#   '14 Oct, 2016',
#   nan,
#   ['Ready Play Games'],
#   ['Ready Play Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Simulation'],
#   0],
#  ['demo',
#   528870,
#   'PANIC at Multiverse High! Demo',
#   '21 Sep, 2016',
#   nan,
#   ['DoubleBear Productions'],
#   ['DoubleBear Productions'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Casual', 'Indie', 'RPG'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   528900,
#   'Multirotor Sim 2',
#   '9 Dec, 2019',
#   nan,
#   ['Vadim Silver'],
#   ['Vadim Silver'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Racing', 'Simulation', 'Sports'],
#   0],
#  ['game',
#   528910,
#   'Golf Pro VR',
#   '19 Sep, 2016',
#   nan,
#   ['Marklar'],
#   ['Marklar'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Sports', 'Early Access'],
#   0],
#  ['game',
#   528930,
#   'Fruit for the Village',
#   '22 May, 2018',
#   '3/5 – VR Focus',
#   ['Eerie Bear Games'],
#   ['Eerie Bear Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   528420,
#   'Evil Orbs',
#   '27 Oct, 2016',
#   nan,
#   ['GoBit Games'],
#   ['GoBit Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['game',
#   528430,
#   'Wells',
#   '29 Jan, 2017',
#   nan,
#   ['Tower Up Studios'],
#   ['Tower Up Studios'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   528450,
#   'Hunt: The Unknown Quarry',
#   '30 Jan, 2017',
#   nan,
#   ['Quicksilver Software, Inc.'],
#   ['Quicksilver Software, Inc.'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'Strategy'],
#   0],
#  ['game',
#   528460,
#   'Rogalia',
#   '15 Oct, 2018',
#   nan,
#   ['TatriX', 'Nanalli'],
#   ['TatriX'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Indie', 'Massively Multiplayer', 'RPG'],
#   0],
#  ['dlc',
#   528480,
#   'Fantasy Grounds - Ultimate NPCs: Skulduggery (5E)',
#   '20 Sep, 2016',
#   nan,
#   ['SmiteWorks USA, LLC'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'RPG', 'Strategy'],
#   0],
#  ['dlc',
#   528490,
#   'Halcyon 6: Starbase Commander - Soundtrack',
#   '9 Sep, 2016',
#   nan,
#   ['Massive Damage, Inc.'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'RPG', 'Simulation', 'Strategy'],
#   0],
#  ['game',
#   528510,
#   'Turbo Pug 3D',
#   '20 Sep, 2016',
#   nan,
#   ['Wulo Games', 'DEADBIT'],
#   ['Back To Basics Gaming'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  ['episode',
#   528520,
#   'Dirty 30: Getting Dirty: The Making of Dirty 30',
#   '23 Sep, 2016',
#   nan,
#   ['Lionsgate'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['game',
#   527960,
#   'Fractured State',
#   '10 Apr, 2020',
#   nan,
#   ['Mechanical Monocle'],
#   ['Mechanical Monocle'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Strategy'],
#   0],
#  ['demo',
#   527980,
#   'Virtual Race Car Engineer 2017 Demo',
#   '4 Oct, 2016',
#   nan,
#   ['Tim McArthur'],
#   ['Monkey Face Software LLC'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Education', 'Utilities'],
#   0],
#  ['game',
#   527990,
#   'Gladiator Trainer',
#   '25 Nov, 2016',
#   nan,
#   ['Pilgrim Adventures'],
#   ['Senpai Studios'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Indie', 'RPG'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   528010,
#   'Eternal Return',
#   '23 Feb, 2017',
#   nan,
#   ['Pathless Games'],
#   ['Pathless Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   528020,
#   'Destroyer',
#   '19 Oct, 2016',
#   nan,
#   ['Arent'],
#   ['Degica'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['dlc',
#   528040,
#   'Axe, Bow & Staff: Digital Artbook',
#   '12 Sep, 2016',
#   nan,
#   ['Clewcat Games'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'RPG'],
#   0],
#  ['game',
#   528060,
#   '東周列萌志 Philosophic Love',
#   '17 Aug, 2018',
#   nan,
#   ['IWPLAY WORLD INTERACTIVE ENTERTAINMENT TECHNOLOGY CO., LTD.'],
#   ['IWPLAY WORLD INTERACTIVE ENTERTAINMENT TECHNOLOGY CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Casual', 'Free to Play', 'Indie'],
#   0],
#  ['game',
#   528070,
#   'Solitaire Beach Season',
#   '10 Oct, 2016',
#   nan,
#   ['Creobit'],
#   ['8Floor'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  ['game',
#   528110,
#   'Tennis Elbow Manager',
#   '14 Oct, 2016',
#   nan,
#   ['Mana Games'],
#   ['Mana Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Sports'],
#   0],
#  ['game',
#   528120,
#   'Darkness and Flame: Born of Fire',
#   '8 Dec, 2016',
#   '“An intriguing plot alone wouldn’t make this such a fantastic game, if not for its one-of-a-kind production. The visuals in Darkness and Flame: Born of Fire are out of this world. Every single scene looks absolutely breathtaking, and with flawless animations as well as epic cutscenes – the art team at FIVE-BN deserves a medal! Besides, the audio in the game is equally commendable. The mood of the music matches the situation in the game very well and the voice-overs showcase enough emotions to make the characters believable.”4.5/5 – All About Casual Game',
#   ['FIVE-BN GAMES'],
#   ['FIVE-BN GAMES'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Casual'],
#   0],
#  ['game',
#   528160,
#   'Solstice Chronicles: MIA',
#   '26 Jul, 2017',
#   '80/100 – GameCritics9/10 – Esports Edition81/100 – CogConnected',
#   ['Ironward'],
#   ['Nkidu Games Inc.'],
#   68,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie', 'RPG'],
#   0],
#  ['game',
#   528180,
#   'Agricola: All Creatures Big and Small',
#   '14 Feb, 2017',
#   "“Superior multiplayer is the raison d'etre of this two-player take on the farmworker placement genre.”4/5 – Pockettactics“Agricola: All Creatures Big and Small is pretty simple and yet has quite a bit of strategy at the same time.”4/5 – Geeky Hobbies",
#   ['DIGIDICED'],
#   ['Asmodee Digital'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'Strategy'],
#   0],
#  ['game',
#   528190,
#   "Carpe Deal 'Em",
#   '28 Nov, 2016',
#   nan,
#   ['DDD Wares'],
#   ['DDD Wares'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': True},
#   ['Simulation', 'Strategy'],
#   0],
#  ['dlc',
#   528220,
#   'Rocket Riot - Soundtrack by SonicPicnic',
#   '19 Oct, 2016',
#   '“The theme on the main menu, “Banana Man”, is one of the catchiest songs of any video game ever.”GameSpew',
#   ['SonicPicnic'],
#   ['Codeglue'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['game',
#   528230,
#   'SYNTHETIK: Legion Rising',
#   '15 Mar, 2018',
#   "“Synthetik turned out to be an amazing surprise - It's probably one of the best rogue-lites that I've played in recent times, and I'm sure I'll keep coing back to it”9/10 – Bonus Stage UK“Synthetik is a rare kind of game and an even rarer kind of roguelike”Third Coast Review - Chicago Arts and Culture“Without a doubt, Synthetik is a game shooter fans owe it to themselves to play.”VG24/7",
#   ['Flow Fire Games'],
#   ['Flow Fire Games', 'WhisperGames'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Indie'],
#   0],
#  ['game',
#   528250,
#   'Patchwork',
#   '6 Dec, 2016',
#   "“Who knew making a patchwork quilt would be so cut throat.”7/10 – GlitchfreeGaming“... if you don't even give this game a chance, you are going to miss out on something great.”9/10 – Altered Confusion",
#   ['DIGIDICED'],
#   ['Asmodee Digital'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   528260,
#   'TITAN SLAYER',
#   '27 Apr, 2017',
#   nan,
#   ['COLOPL, Inc.'],
#   ['COLOPL, Inc.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   528270,
#   'NEON Ultra',
#   '30 Sep, 2016',
#   nan,
#   ['Pixelbark Games'],
#   ['Pixelbark Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action'],
#   0],
#  ['demo',
#   528280,
#   'Codex of Victory Demo',
#   '13 Sep, 2016',
#   nan,
#   ['Ino-Co Plus'],
#   ['1C Company'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'Strategy'],
#   0],
#  ['dlc',
#   528290,
#   'Just Hero Soundtrack',
#   '28 Sep, 2016',
#   nan,
#   ['Anatoliy Loginovskikh'],
#   ['Sometimes You'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  ['game',
#   528300,
#   'Soulless: Ray Of Hope',
#   '18 Oct, 2016',
#   nan,
#   ['Frisky Fatal Games'],
#   ['Meridian4'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Adventure', 'Indie'],
#   0],
#  ['dlc',
#   528310,
#   'Rustangelo PRO (Advanced)',
#   '15 Sep, 2016',
#   nan,
#   ['JaviteSoft'],
#   ['JaviteSoft'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Design & Illustration', 'Utilities'],
#   0],
#  ['episode',
#   527646,
#   'Blade Tutorial: 3Ds Max 2017 and Substance Painter 2: Blade Modeling 7',
#   '3 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   527650,
#   'Blade Tutorial: 3Ds Max 2017 and Substance Painter 2: Blade Texturing 1',
#   '3 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
#   0],
#  ['episode',
#   527651,
#   'Blade Tutorial: 3Ds Max 2017 and Substance Painter 2: Blade Texturing 2',
#   '3 Oct, 2016',
#   nan,
#   nan,
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   nan,
# ...
#   ['Strategy'],
#   0],
#  ['game',
#   521680,
#   'Bandit Kings of Ancient China / 水滸伝・天命の誓い',
#   '21 Feb, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521690,
#   'Romance of the Three Kingdoms Ⅱ / 三國志Ⅱ',
#   '24 Jan, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521700,
#   'NOBUNAGA’S AMBITION: Sengoku Gunyuuden / 信長の野望・戦国群雄伝',
#   '21 Feb, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521710,
#   'Romance of the Three Kingdoms Ⅲ / 三國志Ⅲ',
#   '21 Feb, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521720,
#   'Uncharted Waters / 大航海時代',
#   '18 Apr, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['RPG'],
#   0],
#  ['game',
#   521730,
#   'Romance of the Three Kingdoms Ⅳ with Power Up Kit / 三國志Ⅳ with パワーアップキット',
#   '21 Mar, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521740,
#   "NOBUNAGA'S AMBITION: Bushou Fuunroku / 信長の野望･武将風雲録",
#   '21 Mar, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521750,
#   'Romance of the Three Kingdoms Ⅴ with Power Up Kit / 三國志Ⅴ with パワーアップキット',
#   '18 Apr, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521760,
#   'Taikou Risshiden / 太閤立志伝',
#   '18 Apr, 2017',
#   nan,
#   ['KOEI TECMO GAMES CO., LTD.'],
#   ['KOEI TECMO GAMES CO., LTD.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['RPG'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   521790,
#   'Ancient Frontier',
#   '21 Sep, 2017',
#   "“It is easy to sink dozens of hours into Ancient Frontier, and by and large I enjoyed my time with the game”8 – Chalgyr's Game Room“If you like traditional, hexy turn based strategy there’s no reason you won’t enjoy this and there’s quite a lot of it to go through.”75 – Old Grizzled Gamers“This game is an excellent example of what game developers are capable of when they are given a chance to create something they truly care passionately about.”Early Access Gaming",
#   ['Fair Weather Studios, LLC'],
#   ['Fair Weather Studios, LLC'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['game',
#   521800,
#   'Command Ops 2 Core Game',
#   '15 Feb, 2017',
#   '“One of The Greatest Wargames of All Times”Real and Simulated Waras“Wargames don’t come any smarter or more slacker-friendly than Command Ops 2”Rock Paper Shotgun“Command Ops 2 is an excellent game”Wargamer',
#   ['Panther Games'],
#   ["Lock 'n Load Publishing"],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Free to Play', 'Indie', 'Simulation', 'Strategy'],
#   0],
#  ['game',
#   520840,
#   'Gaming Accelerator 2',
#   '22 Sep, 2016',
#   '“YouTube - Seventh Knight Gaming Accelerator 2 is Freaking Awesome!”The GamerTron Show“YouTube - Gaming Accelerator 2 Review”Mr Dan Zerba (Portuguese)',
#   ['Seventh Knight'],
#   ['Seventh Knight'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Utilities'],
#   0],
#  ['game',
#   520850,
#   'Lost in Secular Love',
#   '28 Oct, 2016',
#   '“《尘沙惑》可以说是一朵奇葩，但是却忍不住多看了两眼，结果被他那颗极其富有魔性、弹吹可破、亮晶晶的——大光头所征服。”\r\n——178游戏频道\n\r\n““人之惑障，如塵沙之多，故稱塵沙惑。”人生中的各種牽絆與糾纏，誘惑與障礙，多如塵沙，在這樣的一個故事裏，脫離輪回，侍奉聖尊，舍棄生而為人的感情，卻壹定要依靠血脈與世界相連，這對於處在這種狀態的人，跟七葉的處境相比，又好得到哪裏呢？故事結尾掉落水中的佛珠，是否是放任清明澄澈的內心沾染塵埃的最好證明？”\r\n——玩家鹿鹿\n',
#   ['YETU GAME'],
#   ['YETU GAME'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   520860,
#   'Impulse of War',
#   '24 Feb, 2017',
#   nan,
#   ['Dmitry Medvedev'],
#   ['Dmitry Medvedev'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action',
#    'Free to Play',
#    'Indie',
#    'Massively Multiplayer',
#    'Racing',
#    'Simulation',
#    'Early Access'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   520871,
#   'Obduction - Original Sound Track',
#   '31 Aug, 2016',
#   nan,
#   ['Robyn Miller', 'Zoo Break Gun Club LLC'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   520873,
#   'Art of Cyan - Digital Art Book',
#   '27 Oct, 2017',
#   nan,
#   ['Cyan'],
#   ['Cyan'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   520900,
#   'Line of Sight - Premium Pack I',
#   '8 Sep, 2016',
#   nan,
#   ['BlackSpot Entertainment'],
#   ['BlackSpot Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['game',
#   520910,
#   'Kokurase Episode 1',
#   '10 Nov, 2016',
#   "“If Kokurase were a person, I would heartily say that senpai has noticed you. I had a great time with the first episode and want to experience more of the misadventures of Kokurase/Cupid's Helpers”83 – RPGFan“As we follow around these incredibly invested teenagers, we can’t help but get caught up in their adventures too. While each of the main club members aren’t completely realized yet, due to this being only the initial adventure, they make a good first impression.”Michibiku“For me personally, I know I’m excited to see what else the Cupid’s Helpers gang will be getting up to, and I’ll be keeping an eye out for the next episode.”3.5 – Hey Poor Player",
#   ['galanti', 'Vaka Game Magazine'],
#   ['Degica', 'Vaka Game Magazine'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Free to Play', 'Indie', 'RPG'],
#   0],
#  ['game',
#   520930,
#   'Pong It! VR',
#   '19 Sep, 2016',
#   nan,
#   ['Mergin Studio'],
#   ['Mergin Studio'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie', 'Simulation', 'Sports', 'Early Access'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['dlc',
#   520970,
#   "Opening song Characters' Version（尘沙惑CV版主题曲）",
#   '15 Sep, 2016',
#   nan,
#   ['YETU GAME'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Adventure', 'Casual', 'Indie', 'Simulation'],
#   0],
#  ['game',
#   520990,
#   'Barrow Hill: The Dark Path',
#   '22 Sep, 2016',
#   nan,
#   ['Shadow Tor Studios'],
#   ['Iceberg Interactive'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie'],
#   0],
#  ['game',
#   521000,
#   'Globe Rush',
#   '2 Sep, 2016',
#   nan,
#   ['Treetop Crew'],
#   ['Treetop Crew'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   521010,
#   'NeuroVoider - Deluxe Upgrade',
#   '31 Aug, 2016',
#   nan,
#   ['Flying Oak Games'],
#   ['Dear Villagers'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Indie', 'RPG'],
#   0],
#  ['demo',
#   521070,
#   'Momento Temporis: Light from the Deep Demo',
#   '24 Aug, 2016',
#   nan,
#   ['Burning Ice Games'],
#   ['Burning Ice Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   521090,
#   'Industry Giant',
#   '2 Oct, 2018',
#   "“Overall well-done business simulation coming from the alpine-republic.”\r\n82% – PC Joker\n\r\n“I enjoyed Industry Giant and would definitely recommend it for its unique blend of transportation network concerns and retail industry competition.”\r\n85% – Gamezilla\n\r\n“...when you've gotten in the swing of things, this can game is an oasis at the end of the desert.”\r\n71% – Gaming Entertainment Monthly\n",
#   ['QLOC'],
#   ['Toplitz Productions'],
#   34,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Simulation', 'Strategy'],
#   0],
#  ['game',
#   521100,
#   "MinosMaze - The Minotaur's Labyrinth",
#   '1 May, 2017',
#   nan,
#   ['RuVe Game Studio'],
#   ['RuVe Game Studio'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Action', 'Adventure', 'Indie'],
#   0],
#  ['game',
#   521110,
#   'Zombie Birds First Encounter Halloween',
#   '19 Oct, 2016',
#   nan,
#   ['magnussoft'],
#   ['magnussoft'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Casual'],
#   0],
#  ['dlc',
#   521120,
#   'Slightly Magic - Music Soundtrack',
#   '29 Sep, 2016',
#   nan,
#   ['Colin Jones & The Potassium Frog'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie'],
#   0],
#  ['dlc',
#   521121,
#   'Slightly Magic - Desktop Wallpapers',
#   '29 Sep, 2016',
#   nan,
#   ['Colin Jones & The Potassium Frog'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie'],
#   0],
#  ['game',
#   521130,
#   'Dots eXtreme',
#   '13 Sep, 2016',
#   nan,
#   ['Starwind Games'],
#   ['Starwind Games'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   521140,
#   'King Machine',
#   '2 Nov, 2016',
#   nan,
#   ['FastRam Design'],
#   ['FastRam Design'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie'],
#   0],
#  ['game',
#   521150,
#   'Another Brick in The Mall',
#   '30 Apr, 2020',
#   nan,
#   ['The Quadsphere'],
#   ['The Quadsphere'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Simulation', 'Strategy'],
#   0],
#  ['dlc',
#   521160,
#   "Tom Clancy's Rainbow Six® Siege - Ash Watch_Dogs Set",
#   '1 Sep, 2016',
#   nan,
#   ['Ubisoft Montreal'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action'],
#   0],
#  ['dlc',
#   521170,
#   'Holiday Skin Bundle (or "Buy Us a Coke") - Trimmer Tycoon',
#   '4 Nov, 2016',
#   nan,
#   ['Improx Games'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Casual', 'Free to Play', 'Indie', 'Simulation', 'Strategy'],
#   0],
#  ['game',
#   521200,
#   'Epic Battle Fantasy 3',
#   '1 Sep, 2016',
#   nan,
#   ['Matt Roszak'],
#   ['Matt Roszak'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Free to Play', 'Indie', 'RPG'],
#   0],
#  ['game',
#   521210,
#   'Timore 5',
#   '25 Aug, 2016',
#   nan,
#   ['Vidas Salavejus'],
#   ['Vidas Salavejus'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie'],
#   0],
#  ['dlc',
#   521220,
#   'ENDLESS™ Legend - Tempest',
#   '14 Oct, 2016',
#   nan,
#   ['AMPLITUDE Studios'],
#   ['SEGA'],
#   82,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['RPG', 'Strategy'],
#   0],
#  ['game',
#   521230,
#   'Stone Age Wars',
#   '9 Jan, 2017',
#   nan,
#   ['Permafrost Studio'],
#   ['Back To Basics Gaming'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Violent', 'Action', 'Indie', 'Strategy'],
#   0],
#  ['game',
#   521250,
#   'Blue Screen Adventures',
#   '2017',
#   nan,
#   ['Bacq Stellan', 'Chris Hédé', 'OtakuMaker Studio'],
#   ['OtakuMaker.com'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Action', 'Adventure', 'Casual', 'Indie', 'Simulation', 'Strategy'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   521280,
#   'Atlantis: Pearls of the Deep',
#   '6 Sep, 2016',
#   nan,
#   ['Alder Games'],
#   ['Legacy Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie'],
#   0],
#  [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#  ['game',
#   520520,
#   'It Comes Around - A Kinetic Novel',
#   '29 Sep, 2016',
#   nan,
#   ['Glass of Water Studios'],
#   ['Afterthought Studios'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Casual', 'Indie', 'RPG', 'Simulation'],
#   0],
#  ['game',
#   520540,
#   'Tribloos 3',
#   '16 Jul, 2018',
#   nan,
#   ['BumpkinBrothers'],
#   ['BumpkinBrothers'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Casual', 'Indie', 'Strategy'],
#   0],
#  ['dlc',
#   520550,
#   'American Truck Simulator - Steering Creations Pack',
#   '14 Sep, 2016',
#   nan,
#   ['SCS Software'],
#   ['SCS Software'],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie', 'Simulation'],
#   0],
#  ['demo',
#   520570,
#   'HoPiKo Demo',
#   '5 Jan, 2017',
#   nan,
#   ['Laser Dog'],
#   ['Merge Games'],
#   82,
#   {'windows': True, 'mac': True, 'linux': False},
#   ['Action', 'Casual', 'Indie'],
#   0],
#  ['dlc',
#   520580,
#   'The Making of Slightly Magic Book - pdf',
#   '29 Sep, 2016',
#   nan,
#   ['Colin Jones & The Potassium Frog'],
#   [''],
#   nan,
#   {'windows': True, 'mac': True, 'linux': True},
#   ['Indie'],
#   0],
#  ['game',
#   520590,
#   'The Journey Of Forgotten Memories',
#   '24 Nov, 2016',
#   nan,
#   ['Forgotten Games'],
#   ['Forgotten Games'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual'],
#   0],
#  ['game',
#   520600,
#   'Purrfect Date - Visual Novel/Dating Simulator',
#   '15 Dec, 2017',
#   "“Purrfect Date is not just for cat lovers, it's for those who love a game with mystery, personality and the heart of British comedy - something a bit bizarre.”Eurogamer“It's cute and funny and clever in ways I didn't expect, and far from the kitty-kissing experience I was braced for. There are feels here that hit out of the blue.”Kotaku“Purrfect Date takes the visual novel, dating simulator genre and takes it in a whole other direction. Not only does it take it in another direction, but it sells it without even a blink of an eye! It’s a game that knows what it is, embraces it and has so much fun doing it you can’t help but feel the same euphoria too!”Hey Poor Player",
#   ['Bae Team'],
#   ['Bossa Studios'],
#   72,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Casual', 'Indie', 'RPG', 'Simulation'],
#   0],
#  ['game',
#   520610,
#   'Drive on Moscow',
#   '27 Oct, 2016',
#   '“If you value the same things that I value in a wargame – historicism, pace, a constant stream of engaging decisions, solid artificial opposition, ambience (the season-related sound effects are rather good) and a well-constructed UI – chances are you’ll emerge wearing a smile whether you’ve won or lost”Rock Paper Shotgun',
#   ['Shenandoah Studio'],
#   ['Slitherine Ltd.'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Strategy'],
#   0],
#  ['dlc',
#   520620,
#   'Small Radios Big Televisions - Soundtrack',
#   '8 Nov, 2016',
#   nan,
#   ['Fire Face Corporation', 'Adult Swim Games'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Adventure', 'Indie'],
#   0],
#  ['dlc',
#   520630,
#   'Fantasy Grounds - 5E: Quests of Doom',
#   '13 Sep, 2016',
#   nan,
#   ['SmiteWorks USA, LLC'],
#   [''],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'RPG', 'Strategy'],
#   0],
#  ['dlc',
#   520640,
#   'Ashes of the Singularity: Escalation - Overlord Scenario Pack DLC',
#   '16 Feb, 2017',
#   nan,
#   ['Stardock Entertainment', 'Oxide Games'],
#   ['Stardock Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Simulation', 'Strategy'],
#   0],
#  ['music',
#   520641,
#   'Ashes of the Singularity: Escalation - Soundtrack DLC',
#   '13 Jan, 2017',
#   nan,
#   ['Stardock Entertainment', 'Oxide Games'],
#   ['Stardock Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Simulation', 'Strategy'],
#   0],
#  ['dlc',
#   520642,
#   'Ashes of the Singularity: Escalation - Epic Map Pack DLC',
#   '16 Feb, 2017',
#   nan,
#   ['Stardock Entertainment', 'Oxide Games'],
#   ['Stardock Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Simulation', 'Strategy'],
#   0],
#  ['dlc',
#   520643,
#   'Ashes of the Singularity: Escalation - Turtle Wars DLC',
#   '16 Feb, 2017',
#   nan,
#   ['Stardock Entertainment', 'Oxide Games'],
#   ['Stardock Entertainment'],
#   nan,
#   {'windows': True, 'mac': False, 'linux': False},
#   ['Indie', 'Simulation', 'Strategy'],
#   0],
#  ...]

# %%
steam1 = pickle.load(open('steam_data_list.p', 'rb'))
steam2 = pickle.load(open('steam_data_list2.p', 'rb'))
steam3 = pickle.load(open('steam_data_list3.p', 'rb'))
steam4 = pickle.load(open('steam_data_list4.p', 'rb'))
steam_data = steam1+steam2+steam3+steam4

len(steam_data)
steam_data_scraped = pd.DataFrame(steam_data, columns = columns)

# %%
x = steam_data_scraped
#x.head()

# %%
x = x[x['metacritic'] > 0 ]
x.sort_values(by = 'metacritic', ascending = False, inplace = True)

with open('steam_scraped_data.p', 'wb') as f:
    pickle.dump(x,f)

# %%
x['steam_appid'].astype(int)
z = x[x['type'] == 'game']
z.shape
# Out:
# (1907, 11)

# %%
# separate the final tally of games with rating scores into three categories.
z.sort_values(by = 'metacritic', ascending = False, inplace = True)
steam_data_top635 =z[0:634]
steam_data_mid635 = z[635:1300]
steam_data_bottom635 = z[1300:]
# Out:
# C:\Users\Ish\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
# Pickle scraped data
# pickle steam backup data.
with open('O_steam_data_scraped.p', 'wb') as f:
    pickle.dump(x,f)

with open('O_steam_top_635.p', 'wb') as f:
    pickle.dump(steam_data_top635,f)

with open('O_steam_bottom_635.p', 'wb') as f:
    pickle.dump(steam_data_bottom635,f)

with open('O_steam_data_middle635.p', 'wb') as f:
    pickle.dump(steam_data_mid635,f)

# %%
steam_full = pickle.load(open('O_steam_data_scraped.p', 'rb'))
list_of_ids = steam_full['steam_appid'].tolist()

# %%
with open('O_steam_ids.p', 'wb') as f:
    pickle.dump(list_of_ids,f)
