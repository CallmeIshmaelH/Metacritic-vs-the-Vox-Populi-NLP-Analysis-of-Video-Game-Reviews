# %%
# import libraries

import pandas as pd
import numpy as np
import requests
from http import client
import getpass 
from time import sleep
pd.set_option('max_columns', None)
pd.set_option('max_rows', None)

# %%
# define secret key 
mykey = getpass.getpass('INPUT KEY: ')
rapidkey = getpass.getpass('RAPID API KEY:')

# %%
# assign selected endpoint urls for quick use in function calls later
games_url =  f"https://rawg-video-games-database.p.rapidapi.com/games?key={mykey}"
developers_url = f"https://rawg-video-games-database.p.rapidapi.com/developers?key={mykey}"
platforms_url = f"https://rawg-video-games-database.p.rapidapi.com/platforms?key={mykey}"
genres_url = f"https://rawg-video-games-database.p.rapidapi.com/genres?key={mykey}"
tags_url = f"https://rawg-video-games-database.p.rapidapi.com/tags?key={mykey}"

# assign selected urls for quick use in function calls later.
headers = {'x-rapidapi-host': "rawg-video-games-database.p.rapidapi.com",'x-rapidapi-key': rapidkey}

# %%
# define a function to request json data from rawg API returning data for selected pages
def rawg_getter(baseurl,headers, x):
    params = {'page':x, 'page_size':40}
    response = requests.get(baseurl, headers=headers,params = params)
    r = response.json()
    
    return r['results']

# %%
# collect data on games from the first 5000 pages
games = list()
for x in range(1,5001):
    games = games + rawg_getter(games_url,headers,x)

len(games)
# Out:
# 200000

# %%
# collect data on developers from first 101 pages
developers = list()
for x in range(1,101):
    developers = developers + rawg_getter(developers_url,headers,x)

len(developers)
# Out:
# 4000

# %%
#collect data on platforms from the first 10 pages
platforms = list()
for x in range(1,3):
    platforms = platforms + rawg_getter(platforms_url, headers, x)

len(platforms)
# Out:
# 51

# %%
# collect data on genres from the first 10 pages
genres = list()
for x in range(1,2):
    genres = genres + rawg_getter(genres_url, headers, x)

len(genres)
# Out:
# 19

# %%
# collect game tags from the first 10 pages
tags = list()
for x in range (1,20):
    tags = tags + rawg_getter(tags_url, headers,x)

# %% [markdown]
# ## Extract desirable data to create a usable dataframe
# From games the information we want will be:
# - id
# - slug
# - name
# - released
# - tba
# - rating
# - rating_top
# - metacritic
# - playtime
# - platforms[0]['platform']['name']
# - platforms[1]['requirements']['minimum']
# - platforms[1]['requirements']['recommended']
# - esrb_rating['name']

# %%
game_data = []
# define a function to collect the data from games
def game_data_getter(json_data, index = 0):
    data = list()
    data.append({'id':json_data[index]['id'],
    'title':json_data[index]['name'],
    'release_date':json_data[index]['released'],
    'tba':json_data[index]['tba'],
    'rating/5':json_data[index]['rating'],
    'top_rating':json_data[index]['rating_top'],
    'metacritic_score':json_data[index]['metacritic'],
    'average_length':json_data[index]['playtime'],
    'platforms': json_data[index]['platforms'],
    'genre':json_data[index]['genres'],
    'esrb_rating':json_data[index]['esrb_rating']})
    return data[0]

# %%
# create loop to populate a list of lists
games_list = []
for g in range(len(games)):
    games_list.append(game_data_getter(games,g))

len(games_list)
# Out:
# 200000

# %%
games_df = pd.DataFrame(games_list)
games_df.head(20)
# Out:
#        id                             title release_date    tba  rating/5  \
# 0    3498                Grand Theft Auto V   2013-09-17  False      4.48
# 1    3328          The Witcher 3: Wild Hunt   2015-05-18  False      4.67
# 2    4200                          Portal 2   2011-04-18  False      4.62
# 3    5286                Tomb Raider (2013)   2013-03-05  False      4.06
# 4    5679       The Elder Scrolls V: Skyrim   2011-11-11  False      4.43
# 5   12020                     Left 4 Dead 2   2009-11-17  False      4.08
# 6    4291  Counter-Strike: Global Offensive   2012-08-21  False      3.58
# 7   13536                            Portal   2007-10-09  False      4.52
# 8     802                     Borderlands 2   2012-09-18  False      4.04
# 9    4062                 BioShock Infinite   2013-03-26  False      4.39
# 10   3439                   Life is Strange   2015-01-29  False      4.11
# 11     28             Red Dead Redemption 2   2018-10-26  False      4.58
# 12   4286                          BioShock   2007-08-21  False      4.38
# 13  13537                       Half-Life 2   2004-11-16  False      4.49
# 14   1030                             Limbo   2010-07-21  False      4.17
# 15   2454                       DOOM (2016)   2016-05-13  False      4.39
# 16  11859                   Team Fortress 2   2007-10-10  False      3.67
# 17   3070                         Fallout 4   2015-11-09  False      3.77
# 18     32                         Destiny 2   2017-09-06  False      3.59
# 19   3939                          PAYDAY 2   2013-08-13  False      3.50
#
#     top_rating  metacritic_score  average_length  \
# 0            5              97.0              71
# 1            5              92.0              49
# 2            5              95.0              11
# 3            4              86.0              11
# 4            5              94.0              45
# 5            4              89.0               9
# 6            4              81.0              62
# 7            5              90.0               4
# 8            4              89.0              10
# 9            5              94.0              12
# 10           5              83.0               7
# 11           5              96.0              21
# 12           5              96.0               3
# 13           5              96.0               7
# 14           4              88.0               3
# 15           5              85.0              11
# 16           4              92.0               9
# 17           4              84.0              44
# 18           4              82.0               4
# 19           4              79.0               9
#
#                                             platforms  \
# 0   [{'platform': {'id': 187, 'name': 'PlayStation...
# 1   [{'platform': {'id': 7, 'name': 'Nintendo Swit...
# 2   [{'platform': {'id': 14, 'name': 'Xbox 360', '...
# 3   [{'platform': {'id': 5, 'name': 'macOS', 'slug...
# 4   [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 5   [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 6   [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 7   [{'platform': {'id': 21, 'name': 'Android', 's...
# 8   [{'platform': {'id': 18, 'name': 'PlayStation ...
# 9   [{'platform': {'id': 14, 'name': 'Xbox 360', '...
# 10  [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 11  [{'platform': {'id': 1, 'name': 'Xbox One', 's...
# 12  [{'platform': {'id': 14, 'name': 'Xbox 360', '...
# 13  [{'platform': {'id': 4, 'name': 'PC', 'slug': ...
# 14  [{'platform': {'id': 18, 'name': 'PlayStation ...
# 15  [{'platform': {'id': 7, 'name': 'Nintendo Swit...
# 16  [{'platform': {'id': 6, 'name': 'Linux', 'slug...
# 17  [{'platform': {'id': 18, 'name': 'PlayStation ...
# 18  [{'platform': {'id': 1, 'name': 'Xbox One', 's...
# 19  [{'platform': {'id': 6, 'name': 'Linux', 'slug...
#
#                                                 genre  \
# 0   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 1   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 2   [{'id': 2, 'name': 'Shooter', 'slug': 'shooter...
# 3   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 4   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 5   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 6   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 7   [{'id': 3, 'name': 'Adventure', 'slug': 'adven...
# 8   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 9   [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 10  [{'id': 3, 'name': 'Adventure', 'slug': 'adven...
# 11  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 12  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 13  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 14  [{'id': 3, 'name': 'Adventure', 'slug': 'adven...
# 15  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 16  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 17  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 18  [{'id': 4, 'name': 'Action', 'slug': 'action',...
# 19  [{'id': 4, 'name': 'Action', 'slug': 'action',...
#
#                                           esrb_rating
# 0       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 1       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 2   {'id': 2, 'name': 'Everyone 10+', 'slug': 'eve...
# 3       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 4       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 5       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 6       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 7           {'id': 3, 'name': 'Teen', 'slug': 'teen'}
# 8       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 9       {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 10      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 11      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 12      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 13      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 14          {'id': 3, 'name': 'Teen', 'slug': 'teen'}
# 15      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 16      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 17      {'id': 4, 'name': 'Mature', 'slug': 'mature'}
# 18          {'id': 3, 'name': 'Teen', 'slug': 'teen'}
# 19  {'id': 5, 'name': 'Adults Only', 'slug': 'adul...

# %%
platforms = games_df['platforms']
# define a function to strip platform names from platform dictionary.
def platform_names(platform_list):
    platform_name_list = []
    for platform in platform_list:
        platform_name_list.append(platform['platform']['name'])
        
    return platform_name_list

games_df['platforms'] = platforms.apply(lambda x : platform_names(x))

# %%
# define a function to replace genres with genre names and create a new column for genre_ids
def genre_id(genres_list):
    genre_ids_list = []
    for genre in genres_list:
        genre_ids_list.append(genre['id'])
    return genre_ids_list

games_df['genre_ids'] = games_df['genre'].apply(lambda x: genre_id(x))

def genre_names(genres_list):
    genre_names_list = []
    for genre in genres_list:
        genre_names_list.append(genre['name'])
    return genre_names_list

games_df['genre'] = games_df['genre'].apply(lambda x:genre_names(x))

# %%
# define a function to get the ESRB rating names.
esrb = games_df['esrb_rating']

def esrb_label(esrb_dict):
    if esrb_dict != None:
        return esrb_dict['name']
    else:
        return np.NaN


games_df['esrb_rating'] = games_df['esrb_rating'].apply(lambda x: esrb_label(x))

# %%
games_df.head()
# Out:
#      id                        title release_date    tba  rating/5  \
# 0  3498           Grand Theft Auto V   2013-09-17  False      4.48
# 1  3328     The Witcher 3: Wild Hunt   2015-05-18  False      4.67
# 2  4200                     Portal 2   2011-04-18  False      4.62
# 3  5286           Tomb Raider (2013)   2013-03-05  False      4.06
# 4  5679  The Elder Scrolls V: Skyrim   2011-11-11  False      4.43
#
#    top_rating  metacritic_score  average_length  \
# 0           5              97.0              71
# 1           5              92.0              49
# 2           5              95.0              11
# 3           4              86.0              11
# 4           5              94.0              45
#
#                                            platforms  \
# 0  [PlayStation 5, PlayStation 4, PlayStation 3, ...
# 1     [Nintendo Switch, Xbox One, PC, PlayStation 4]
# 2  [Xbox 360, macOS, Linux, PC, PlayStation 3, Xb...
# 3  [macOS, Xbox One, PlayStation 4, PC, Xbox 360,...
# 4     [PC, Nintendo Switch, Xbox 360, PlayStation 3]
#
#                       genre   esrb_rating  genre_ids
# 0       [Action, Adventure]        Mature     [4, 3]
# 1  [Action, Adventure, RPG]        Mature  [4, 3, 5]
# 2         [Shooter, Puzzle]  Everyone 10+     [2, 7]
# 3       [Action, Adventure]        Mature     [4, 3]
# 4             [Action, RPG]        Mature     [4, 5]

# %%
games_df.sort_values(by='metacritic_score', ascending= False, inplace = True)
games_df.head(50)
# Out:
#            id                                              title release_date  \
# 1473    25097               The Legend of Zelda: Ocarina of Time   1998-11-21
# 61829  407559                                 Soulcalibur (1998)   1998-07-30
# 6545    54751                                        Soulcalibur   1998-07-30
# 0        3498                                 Grand Theft Auto V   2013-09-17
# 3958    56123                                      Metroid Prime   2002-11-17
# 531     28026                                Super Mario Odyssey   2017-10-26
# 265     22511            The Legend of Zelda: Breath of the Wild   2017-03-02
# 1741    27024                                 Super Mario Galaxy   2007-11-12
# 2866    27036                               Super Mario Galaxy 2   2010-05-23
# 2347    28495                                       Perfect Dark   2000-05-22
# 7507    52995                                       Gran Turismo   1997-12-22
# 5041    54403                               GoldenEye 007 (1997)   1997-08-23
# 12       4286                                           BioShock   2007-08-21
# 13      13537                                        Half-Life 2   2004-11-16
# 65      18080                                          Half-Life   1998-11-19
# 432     22513                         Uncharted 2: Among Thieves   2009-10-13
# 1431   401808                                Half-Life 2: Update   2015-03-27
# 2950    57842                                           Tekken 3   1997-03-20
# 2417    52370                Metal Gear Solid 2: Sons of Liberty   2001-11-12
# 11         28                              Red Dead Redemption 2   2018-10-26
# 263     10073                           Divinity: Original Sin 2   2017-09-14
# 2459    25924                 The Legend of Zelda: Majora's Mask   2000-04-27
# 129      4544                                Red Dead Redemption   2010-05-18
# 22957  364800           The Legend of Zelda: Collector's Edition   2003-11-07
# 155      3990                                     The Last Of Us   2013-06-14
# 2        4200                                           Portal 2   2011-04-18
# 4577    45958                          XCOM 2: War of the Chosen   2017-08-29
# 1330   339958                                    Persona 5 Royal   2020-03-31
# 59       3636                          The Last Of Us Remastered   2014-07-29
# 11916  378578              Grand Theft Auto IV: Complete Edition   2010-10-27
# 5998    30799                   Baldur's Gate II: Shadows of Amn   2000-09-21
# 1867    25096            The Legend of Zelda: A Link to the Past   1991-11-21
# 20       4459                                Grand Theft Auto IV   2008-04-29
# 4        5679                        The Elder Scrolls V: Skyrim   2011-11-11
# 1159    57607                                   Metal Gear Solid   1998-09-03
# 448     15642  The Elder Scrolls IV: Oblivion Game of the Yea...   2009-06-16
# 7810    42180      The Elder Scrolls V: Skyrim Legendary Edition   2013-06-04
# 2636    29593                                             Diablo   1996-12-31
# 6887    52815                                  Command & Conquer   1995-08-31
# 626      5678                     The Elder Scrolls IV: Oblivion   2006-03-20
# 5862    52799                                       Chrono Cross   1999-11-18
# 62       4806                                      Mass Effect 2   2010-01-26
# 22      58175                                         God of War   2018-04-20
# 1660    28581                                     The Orange Box   2008-01-01
# 9        4062                                  BioShock Infinite   2013-03-26
# 20935   27714         Super Mario Advance 4: Super Mario Bros. 3   2003-07-11
# 284     53341                                      Jet Set Radio   2000-06-29
# 917      3469           Metal Gear Solid 4: Guns of the Patriots   2008-06-12
# 707     13780                        Sid Meier's Civilization IV   2005-10-25
# 79        430                        Grand Theft Auto: Vice City   2002-10-27
#
#          tba  rating/5  top_rating  metacritic_score  average_length  \
# 1473   False      4.42           5              99.0               7
# 61829  False      0.00           0              98.0               0
# 6545   False      4.43           5              98.0               6
# 0      False      4.48           5              97.0              71
# 3958   False      4.38           5              97.0               2
# 531    False      4.44           5              97.0               0
# 265    False      4.56           5              97.0             121
# 1741   False      4.40           5              97.0              28
# 2866   False      4.37           5              97.0              18
# 2347   False      3.99           5              97.0              10
# 7507   False      4.28           4              96.0               0
# 5041   False      4.36           5              96.0               0
# 12     False      4.38           5              96.0               3
# 13     False      4.49           5              96.0               7
# 65     False      4.40           5              96.0               3
# 432    False      4.39           5              96.0              13
# 1431   False      4.04           5              96.0               1
# 2950   False      4.41           5              96.0               1
# 2417   False      4.39           5              96.0              12
# 11     False      4.58           5              96.0              21
# 263    False      4.39           5              95.0              22
# 2459   False      4.35           5              95.0              23
# 129    False      4.41           5              95.0               7
# 22957  False      4.38           4              95.0               0
# 155    False      4.59           5              95.0              15
# 2      False      4.62           5              95.0              11
# 4577   False      4.36           5              95.0               0
# 1330   False      4.79           5              95.0               0
# 59     False      4.69           5              95.0              16
# 11916  False      4.55           5              95.0               0
# 5998   False      4.36           5              95.0               1
# 1867   False      4.38           5              95.0              28
# 20     False      4.24           4              95.0               9
# 4      False      4.43           5              94.0              45
# 1159   False      4.44           5              94.0               1
# 448    False      4.29           5              94.0               4
# 7810   False      4.63           5              94.0               0
# 2636   False      4.40           5              94.0               1
# 6887   False      4.31           5              94.0               0
# 626    False      4.34           5              94.0               4
# 5862   False      4.41           5              94.0              42
# 62     False      4.48           5              94.0              22
# 22     False      4.60           5              94.0              20
# 1660   False      4.51           5              94.0               6
# 9      False      4.39           5              94.0              12
# 20935  False      4.00           4              94.0               0
# 284    False      3.43           4              94.0               1
# 917    False      4.40           5              94.0              20
# 707    False      4.08           4              94.0               2
# 79     False      4.45           5              94.0               2
#
#                                                platforms  \
# 1473                 [Nintendo 64, GameCube, Wii U, Wii]
# 61829                              [Dreamcast, Xbox 360]
# 6545       [Xbox One, iOS, Xbox 360, Android, Dreamcast]
# 0      [PlayStation 5, PlayStation 4, PlayStation 3, ...
# 3958                                     [GameCube, Wii]
# 531                                    [Nintendo Switch]
# 265                             [Wii U, Nintendo Switch]
# 1741                       [Wii, Nintendo Switch, Wii U]
# 2866                                        [Wii U, Wii]
# 2347                   [Xbox 360, Xbox One, Nintendo 64]
# 7507                                       [PlayStation]
# 5041                                       [Nintendo 64]
# 12     [Xbox 360, PlayStation 3, iOS, macOS, PlayStat...
# 13           [PC, Xbox 360, Linux, Xbox, Android, macOS]
# 65                     [PC, PlayStation 2, macOS, Linux]
# 432                       [PlayStation 4, PlayStation 3]
# 1431                                                [PC]
# 2950                                       [PlayStation]
# 2417   [PlayStation 2, PlayStation 3, PS Vita, Xbox 3...
# 11                         [Xbox One, PC, PlayStation 4]
# 263       [PlayStation 4, PC, Xbox One, Nintendo Switch]
# 2459                           [Nintendo 64, Wii U, Wii]
# 129                  [Xbox One, Xbox 360, PlayStation 3]
# 22957                                         [GameCube]
# 155                                      [PlayStation 3]
# 2      [Xbox 360, macOS, Linux, PC, PlayStation 3, Xb...
# 4577         [PC, Xbox One, PlayStation 4, macOS, Linux]
# 1330                                     [PlayStation 4]
# 59                                       [PlayStation 4]
# 11916                      [PC, PlayStation 3, Xbox 360]
# 5998                                [PC, Android, macOS]
# 1867   [Wii, Wii U, Nintendo 3DS, Nintendo Switch, Ga...
# 20               [Xbox 360, PlayStation 3, Xbox One, PC]
# 4         [PC, Nintendo Switch, Xbox 360, PlayStation 3]
# 1159      [PlayStation, PSP, PC, PlayStation 3, PS Vita]
# 448                        [PlayStation 3, Xbox 360, PC]
# 7810                       [PC, PlayStation 3, Xbox 360]
# 2636                            [PlayStation, macOS, PC]
# 6887   [PC, PlayStation, Classic Macintosh, SEGA Saturn]
# 626              [PC, Xbox One, Xbox 360, PlayStation 3]
# 5862          [PlayStation 3, PSP, PS Vita, PlayStation]
# 62               [PC, Xbox One, PlayStation 3, Xbox 360]
# 22                        [PlayStation 4, PlayStation 5]
# 1660                       [Xbox 360, PC, PlayStation 3]
# 9      [Xbox 360, Nintendo Switch, PC, Linux, PlaySta...
# 20935                                 [Game Boy Advance]
# 284    [iOS, Xbox 360, Android, Game Boy Advance, Dre...
# 917                                      [PlayStation 3]
# 707                                          [macOS, PC]
# 79     [PlayStation 2, PlayStation 3, PlayStation 4, ...
#
#                               genre   esrb_rating    genre_ids
# 1473       [Action, Adventure, RPG]      Everyone    [4, 3, 5]
# 61829                    [Fighting]          Teen          [6]
# 6545             [Action, Fighting]           NaN       [4, 6]
# 0               [Action, Adventure]        Mature       [4, 3]
# 3958   [Action, Shooter, Adventure]           NaN    [4, 2, 3]
# 531            [Arcade, Platformer]  Everyone 10+     [11, 83]
# 265        [Action, Adventure, RPG]  Everyone 10+    [4, 3, 5]
# 1741                   [Platformer]      Everyone         [83]
# 2866                   [Platformer]           NaN         [83]
# 2347                      [Shooter]        Mature          [2]
# 7507                       [Racing]           NaN          [1]
# 5041                      [Shooter]           NaN          [2]
# 12                [Action, Shooter]        Mature       [4, 2]
# 13                [Action, Shooter]        Mature       [4, 2]
# 65                [Action, Shooter]        Mature       [4, 2]
# 432    [Action, Shooter, Adventure]          Teen    [4, 2, 3]
# 1431                      [Shooter]        Mature          [2]
# 2950                     [Fighting]           NaN          [6]
# 2417   [Action, Shooter, Adventure]        Mature    [4, 2, 3]
# 11              [Action, Adventure]        Mature       [4, 3]
# 263                 [RPG, Strategy]           NaN      [5, 10]
# 2459            [Action, Adventure]           NaN       [4, 3]
# 129               [Action, Shooter]        Mature       [4, 2]
# 22957      [Action, Adventure, RPG]      Everyone    [4, 3, 5]
# 155             [Action, Adventure]        Mature       [4, 3]
# 2                 [Shooter, Puzzle]  Everyone 10+       [2, 7]
# 4577                     [Strategy]           NaN         [10]
# 1330               [Adventure, RPG]        Mature       [3, 5]
# 59              [Action, Adventure]        Mature       [4, 3]
# 11916           [Action, Adventure]   Adults Only       [4, 3]
# 5998                [RPG, Strategy]           NaN      [5, 10]
# 1867            [Action, Adventure]           NaN       [4, 3]
# 20              [Action, Adventure]        Mature       [4, 3]
# 4                     [Action, RPG]        Mature       [4, 5]
# 1159   [Action, Shooter, Adventure]        Mature    [4, 2, 3]
# 448                           [RPG]        Mature          [5]
# 7810               [Adventure, RPG]        Mature       [3, 5]
# 2636                  [Action, RPG]           NaN       [4, 5]
# 6887                     [Strategy]           NaN         [10]
# 626                           [RPG]        Mature          [5]
# 5862                          [RPG]          Teen          [5]
# 62                    [Action, RPG]        Mature       [4, 5]
# 22              [Action, Adventure]        Mature       [4, 3]
# 1660                      [Shooter]          Teen          [2]
# 9                 [Action, Shooter]        Mature       [4, 2]
# 20935                  [Platformer]      Everyone         [83]
# 284    [Action, Sports, Platformer]          Teen  [4, 15, 83]
# 917               [Action, Shooter]        Mature       [4, 2]
# 707                      [Strategy]  Everyone 10+         [10]
# 79              [Action, Adventure]        Mature       [4, 3]

# %%
games_df.to_csv('games_data.csv')

# %%
games_df.isna().sum()
# Out:
# id                       0
# title                    0
# release_date          7725
# tba                      0
# rating/5                 0
# top_rating               0
# metacritic_score    194359
# average_length           0
# platforms                0
# genre                    0
# esrb_rating         180004
# genre_ids                0
# dtype: int64

# %%
cleaned_game_data = games_df.dropna()
cleaned_game_data.shape
# Out:
# (3099, 12)

# %%
cleaned_game_data = cleaned_game_data.sort_values(by='metacritic_score')
cleaned_game_data.to_csv('reduced_games_data.csv')
